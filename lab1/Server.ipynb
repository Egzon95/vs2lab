# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# Hello, I am the Server
# [STARTING] starting the Server
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
# [CLIENT] handling client
#     [GETALL] GETALL handler started
#     [ANSWER_LENGTH] Sending the length: 10527
#     [ANSWER] Sending the Answer: {'James': 235007, 'Luke': 571708, 'Holy': 839655, 'Maria': 229351, 'Noah': 123456, 'Egzon': 666666, 'Yannik': 180546, 'Julian': 555555, 'hkeqtzjuacgw': 1, 'zosuciudxriv': 2, 'dieivpgffajf': 3, 'wtgktgblxtrs': 4, 'wlgsqrfidihg': 5, 'sbwgbvnazxzh': 6, 'zenqwcojzzoc': 7, 'qyqprarfwkok': 8, 'ljijbfjlzkqp': 9, 'yprtwoqwxkxn': 10, 'afcacldwmmmi': 11, 'zlbnucpibbbu': 12, 'iczggmurbxgl': 13, 'vegzjotycgtk': 14, 'thoaaqsldmlv': 15, 'hjdtxmbufbtk': 16, 'hsjahvqhmlyg': 17, 'sttugwfizohx': 18, 'moieqbxtfcdn': 19, 'xzxptcfswqah': 20, 'gstevszicrsx': 21, 'kcyacvjzsnun': 22, 'pdhfoingjryx': 23, 'rzpksyjrniwu': 24, 'fkwyvxoupdqx': 25, 'uuxstiinsfxk': 26, 'mxekqcacoxmw': 27, 'ksdnkvzfkleq': 28, 'cmkomhzraopa': 29, 'omtfmvsdbpky': 30, 'ifpmcghqfhzl': 31, 'abnjbtxembib': 32, 'ehfxsxzeyhlu': 33, 'skhojrlchhdw': 34, 'aurfwgsxrsdq': 35, 'hypczuegtuaa': 36, 'zlasnsfinidj': 37, 'mhownpppufas': 38, 'rvntppdrquyn': 39, 'ozxzmslmjorm': 40, 'smzxuijohwon': 41, 'odutipfevzwp': 42, 'btchzdniphev': 43, 'rljrgrcsbpju': 44, 'qeozfunefvkv': 45, 'vrokdllisypm': 46, 'rxrsenmoztio': 47, 'uqmhdyxnakpn': 48, 'gxyhghbpzwli': 49, 'cmrolewsxtvb': 50, 'gpkrxdnuqjfq': 51, 'vxzvevjbyynf': 52, 'okeljtiakfhy': 53, 'pybpcmdpaabl': 54, 'lwhtlrizfuet': 55, 'pjuzkupmhxrq': 56, 'slouyahdlzmf': 57, 'upwrburerfcv': 58, 'fpvsuvkzwttx': 59, 'owrvaniwngjd': 60, 'rdagklxhydru': 61, 'mtdufhgkmcak': 62, 'wwuamqruvrgw': 63, 'qsdrkzrqdeba': 64, 'jqzktfomlecb': 65, 'itvnyunqbvbq': 66, 'adwyxgqlgsyl': 67, 'jjyftqiiljet': 68, 'nnvikivxtust': 69, 'hbraffxklknp': 70, 'vlttdnaygswl': 71, 'gfetmoheqztv': 72, 'tqnhxwoolfwc': 73, 'fmhqlkpasavp': 74, 'dnxpwsgkgcys': 75, 'lerhbbfarljs': 76, 'zabvidrygrvv': 77, 'jdcyjnyunzho': 78, 'mxmzwqywplpm': 79, 'bldggdenjqvs': 80, 'hhjzzrsbaqbi': 81, 'mltlxfrjugge': 82, 'wuogfpnnkgsa': 83, 'iqswrwhpuhwv': 84, 'abgcpsdmyaqj': 85, 'hzsnubdgsecw': 86, 'ndjsaourefgc': 87, 'uaafotcdqbyn': 88, 'vctcsmvxobiv': 89, 'ssmclbowwhrt': 90, 'hcoljnwwcqon': 91, 'clntjkilwgon': 92, 'bbqysdcrgiyu': 93, 'msunbcbyijsn': 94, 'gchxdfgybbbd': 95, 'zledyopafcde': 96, 'uyklrvqguqqo': 97, 'pafijcxjoonq': 98, 'lsvvkmbvoceo': 99, 'qgmdbpyamqfe': 100, 'vbhbifhpqvoh': 101, 'vkzlzsxpqovs': 102, 'wypokaktnyaj': 103, 'vaynfusirlgv': 104, 'yasjtdqucseb': 105, 'hptbpbhqicig': 106, 'dsyijqlpvrrx': 107, 'qbimrzllfmbc': 108, 'fvwuyhusttnm': 109, 'krpdibnrzaqp': 110, 'evvtmbnirzcd': 111, 'zpxqekwguxzf': 112, 'ffxtnukuttjt': 113, 'rsfidnranzku': 114, 'qbcftgsytfgs': 115, 'yyepnjfreera': 116, 'eevxxquettjr': 117, 'aikygtlxtdjb': 118, 'yyvpgsauotlf': 119, 'qppbyvnjoyci': 120, 'kuxvhcrghppe': 121, 'kavlumxundpc': 122, 'owniafeovcuc': 123, 'azxvqoxhxzxa': 124, 'uezqjcqpwcvg': 125, 'lasotokirntx': 126, 'rcfbmwehaptg': 127, 'dafsvemgxzrl': 128, 'wfphoiifvocv': 129, 'xfahzxnlwcxp': 130, 'zdgvalbavdtb': 131, 'ierbzmpqducx': 132, 'jydiugrcenmf': 133, 'stvuncsgsytx': 134, 'nofzpanlftap': 135, 'byemorrzlchh': 136, 'gdekrdyriptn': 137, 'klqvlmimxzpc': 138, 'craggllvdszq': 139, 'spirlgpqqtrq': 140, 'ackjydwqfjug': 141, 'tjbetuzqpxcn': 142, 'sjpfmljszjcd': 143, 'sjquhzqnnwrd': 144, 'mvdwbfykzbht': 145, 'pjlmzbsmcvym': 146, 'rwukivovhxix': 147, 'dtamxoysbfgn': 148, 'gjgzwhikoric': 149, 'kwcnacaptzhq': 150, 'oqnyyfwvlskr': 151, 'wayhviehyafa': 152, 'nzooondvkuwn': 153, 'wupbysbghrvw': 154, 'qqymujjloznx': 155, 'cwdsvaqntbsd': 156, 'lgpkzieebptu': 157, 'paqmmnwbxbkq': 158, 'miedrajljcky': 159, 'febpyxmqzwrg': 160, 'eqlcvlpfnrea': 161, 'jnmnwqzqbygx': 162, 'oejcoauukwcs': 163, 'cmdxzbopqwxo': 164, 'xhqoanochlgt': 165, 'xmcoemwprvoa': 166, 'jtoygykqycrl': 167, 'odaxshfbasvd': 168, 'uibygalsyavq': 169, 'hiotqjhewfpp': 170, 'bzeaacmwjxua': 171, 'xtduuvcvgmal': 172, 'yezmceafwkyh': 173, 'rhtitbdvumrk': 174, 'yjagpvavtzur': 175, 'sflxwhjsdghz': 176, 'ncwujgbwthpp': 177, 'khbkkveixpsx': 178, 'zioahakqgomn': 179, 'ukwtqkwatbqz': 180, 'yvndovyzdtwx': 181, 'hbupebuzuyhm': 182, 'ulnyhthplzuj': 183, 'pprkumxzzskw': 184, 'flvievxvmaiq': 185, 'delmrnfhrwoe': 186, 'uqldohtfblpl': 187, 'iahxvzxvdwq ...
#     [GET] GET handler started
#         [MESSAGE_LENGTH] 5
#         [MESSAGE] James
#     [ANSWER_LENGTH] Sending the length: 6
#     [ANSWER] Sending the Answer: 235007
#     [GET] GET handler started
#         [MESSAGE_LENGTH] 4
#         [MESSAGE] Noah
#     [ANSWER_LENGTH] Sending the length: 6
#     [ANSWER] Sending the Answer: 123456
#     [GET] GET handler started
#         [MESSAGE_LENGTH] 4
#         [MESSAGE] Exon
#     [ANSWER_LENGTH] Sending the length: 9
#     [ANSWER] Sending the Answer: No Result
#     [DISCONNECT] DISCONNECT handler started
# I'm done!
# [CLOSED] Connection has been closed
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
# [CLIENT] handling client

# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# Hello, I am the Server
# [STARTING] starting the Server
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
# [CLIENT] handling client
#     [GETALL] GETALL handler started
#     [ANSWER_LENGTH] Sending the length: 10527
#     [ANSWER] Sending the Answer: {'James': 235007, 'Luke': 571708, 'Holy': 839655, 'Maria': 229351, 'Noah': 123456, 'Egzon': 666666, 'Yannik': 180546, 'Julian': 555555, 'soqadwthqyfw': 1, 'dcpgwlujmmao': 2, 'muhuwqhaqibc': 3, 'hhybgtoqvepp': 4, 'bmpowgrahudi': 5, 'nexpsktzcneq': 6, 'rmgovtougzhf': 7, 'rvxxzeqyrqid': 8, 'cseirbbhqiqz': 9, 'wrskplwlyyza': 10, 'jvoykfwdswrg': 11, 'lqnexspbquxr': 12, 'wulhkfyyobuq': 13, 'grjizjhghoqu': 14, 'redtchaqxlax': 15, 'ysuhqodtoeir': 16, 'nsncyrslzmzb': 17, 'imwdlgdzcslx': 18, 'hcafxfciddbt': 19, 'bymltneynijr': 20, 'ljxfxtrykelz': 21, 'vlsibgrbmalo': 22, 'lrbextznacdx': 23, 'utltytbrqnqn': 24, 'glvoocblpyny': 25, 'gzkoqxrruwru': 26, 'kxuwowhnrzqh': 27, 'vovdmivtepzj': 28, 'nsvvsyedrvvs': 29, 'jabnnoinvnji': 30, 'ghuatxllwwal': 31, 'znrshgwndxff': 32, 'iynqhmyecrzl': 33, 'illergzkbdja': 34, 'ommgnwlnztwu': 35, 'wzdvlvebgigb': 36, 'sqlprxuonhtx': 37, 'eqhidpofyuvj': 38, 'osraplvkvmhy': 39, 'suwdfdqzvkmc': 40, 'hixwjjxnhqzs': 41, 'spghmchnnpcp': 42, 'yibohluocakj': 43, 'gztplnfvhplk': 44, 'jqnadsxybozk': 45, 'qvpredxequwi': 46, 'vipflklzforu': 47, 'izqzgxcvnmxi': 48, 'tgfztbumlrwu': 49, 'zaodsluuahlp': 50, 'cnqkntbxcgdr': 51, 'xxdtmokafocz': 52, 'cumfcjyyfois': 53, 'zhdfsmiuzgov': 54, 'rvcgkkvtimxg': 55, 'nyjkdoyiubxz': 56, 'xzuuwuntabow': 57, 'bvyfeuqwdnku': 58, 'fyhbbbfjluin': 59, 'enjhsjvdanhb': 60, 'kyraofkgktkj': 61, 'flugfmqlsvja': 62, 'hteochzwgdsc': 63, 'obafwmxtqdwg': 64, 'dzhtmjfnirfm': 65, 'bcxyrzohnpjg': 66, 'mpvrtamubzeu': 67, 'nrwhllqmgpgo': 68, 'lonfsmeentak': 69, 'zspadsrdvqtu': 70, 'yfqsowonopfo': 71, 'vytbltwbjerx': 72, 'kbblvvgdcukj': 73, 'kdycpkjntgtq': 74, 'uxctwqstbadu': 75, 'wccwokycqvzo': 76, 'inxgmunsgycd': 77, 'qcoxwqbhhvnr': 78, 'owavfqkhuapq': 79, 'kffcyysokubw': 80, 'kjtencahkscg': 81, 'zpysuqsbkzwm': 82, 'txkygcvahlxf': 83, 'bjbgeotdzkfd': 84, 'senrejefizhe': 85, 'jrlxoulqhkpt': 86, 'woczsugqtmpp': 87, 'wuiistpijwzd': 88, 'lsxlfrywsvqu': 89, 'wtaxbrevcbmo': 90, 'zvtbiwanuvfq': 91, 'rgimdzfavofr': 92, 'edpowyrpcueg': 93, 'mplthnojtpom': 94, 'cltgyxqsqotp': 95, 'lqzmztrwxgkt': 96, 'jolldnnffgyj': 97, 'kkzlntmvevbx': 98, 'flphigyntman': 99, 'vwpfrldffzgz': 100, 'xeqffvjlmvky': 101, 'llkevxwdlmol': 102, 'xhptjwycgxot': 103, 'ahzvbqblufba': 104, 'cvxvctkfqggi': 105, 'whzheyuaugzh': 106, 'xwnumkmkcgfs': 107, 'onbhacrnhdfq': 108, 'avgxxnagvpsx': 109, 'tdofyhogoofh': 110, 'wktmcektqsoi': 111, 'ohylspzbzsiv': 112, 'kfuajvddwhus': 113, 'wtwlaobwfrfx': 114, 'tfsdgobylxgp': 115, 'baqbfumwjxop': 116, 'uevfxqpardtu': 117, 'asppdbmerjrz': 118, 'ggqgwmynbybc': 119, 'vkfgpjrjqdnu': 120, 'pxliswkxgtog': 121, 'vuycmwqtymbx': 122, 'aypxyobivzia': 123, 'vbcqhpiprwuw': 124, 'ezdoavlwyxor': 125, 'snyjazfwxine': 126, 'bpjahgdlsxkq': 127, 'qrmqspiskzig': 128, 'fvwajubidrhk': 129, 'iiarjigpybth': 130, 'rhmlklmvwdry': 131, 'zimvbmxxdtbs': 132, 'hfwgjvtkglry': 133, 'ndysjthctdoy': 134, 'bjfsecfmlrrl': 135, 'mujkvodiozjp': 136, 'yadgbasftjih': 137, 'szsabbfawufu': 138, 'amwotfmfhkxc': 139, 'xjrfwjozhqsb': 140, 'crouaiwydvxo': 141, 'pvwrmtwzcolo': 142, 'rqfstzplzhuf': 143, 'kjtlrikfxcyw': 144, 'ehchjfotygam': 145, 'xgatcwetzlmg': 146, 'tdwgmltmflif': 147, 'eijlkxegnsjo': 148, 'vbhvzyppcbhf': 149, 'zruvadqctouv': 150, 'xplejyflhvgp': 151, 'evcnpkkxwrma': 152, 'ifharloiyhib': 153, 'gynubdqojuxr': 154, 'iodgzgzbveba': 155, 'ydbqrfuzncuk': 156, 'gypylaaxidki': 157, 'fgwhtrfyabtj': 158, 'kbjiifxymebq': 159, 'rzcivdlgvhml': 160, 'omjgwtcddedz': 161, 'jybuqcrduqml': 162, 'gdeltovtwumx': 163, 'asgquxkrtnsn': 164, 'tuvvnbgormkh': 165, 'idgvxtcltiqn': 166, 'nxlirwejyobp': 167, 'oosctkahkaje': 168, 'swubpxqsjktc': 169, 'itdpeubheznp': 170, 'ohudjngajjmu': 171, 'pobrdvdryhwe': 172, 'wwzqvbaohnpv': 173, 'pzvmujnnstlz': 174, 'zaeqwdtnvlnf': 175, 'zyprrigwvxev': 176, 'okvnxedsyrdr': 177, 'tsicwkbwzkmi': 178, 'rgynknffhlwi': 179, 'sznwuuxfiyvz': 180, 'gwdfsbztycqj': 181, 'pboilsdzzjpo': 182, 'xpmrjvrdohew': 183, 'kzcgtxnevbnk': 184, 'anyzpfpqhewy': 185, 'umxeewcdcnqb': 186, 'yhavlmqivobp': 187, 'knvlkxirerr ...
#     [GET] GET handler started
#         [MESSAGE_LENGTH] 4
#         [MESSAGE] Noah
#     [ANSWER_LENGTH] Sending the length: 6
#     [ANSWER] Sending the Answer: 123456
#     [GET] GET handler started
#         [MESSAGE_LENGTH] 5
#         [MESSAGE] Exx0n
#     [ANSWER_LENGTH] Sending the length: 9
#     [ANSWER] Sending the Answer: No Result
#     [DISCONNECT] DISCONNECT handler started
# I'm done!
# [CLOSED] Connection has been closed
#
# [CONNECTING] looking for connection
# [CLIENT] handling client
#     [GET] GET handler started
#         [MESSAGE_LENGTH] 5
#         [MESSAGE] Egzon
#     [ANSWER_LENGTH] Sending the length: 6
#     [ANSWER] Sending the Answer: 666666
#     [DISCONNECT] DISCONNECT handler started
# I'm done!
# [CLOSED] Connection has been closed
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
# ...
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
#     [TIMEOUT] trying again
#
# [CONNECTING] looking for connection
